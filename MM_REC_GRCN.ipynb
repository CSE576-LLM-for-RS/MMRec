# %%
# !git clone https://github.com/enoche/MMRec.git
# Out:
# Cloning into 'MMRec'...
# remote: Enumerating objects: 381, done.
# remote: Counting objects: 100% (130/130), done.
# remote: Compressing objects: 100% (64/64), done.
# remote: Total 381 (delta 89), reused 75 (delta 66), pack-reused 251 (from 1)
# Receiving objects: 100% (381/381), 624.51 KiB | 2.58 MiB/s, done.
# Resolving deltas: 100% (174/174), done.

# %% [markdown]
# # How to use this Collab
# - Replace all files under `MMRec/src/utils/`based on the github
# - Replace the `MMRec/src/models/grcn.py` based on the github
# - Replace the `MMRec/src/configs/overall.yaml` based on the github
# - Replace the `MMRec/src/common/abstract_recommender.py` based on the github
# - Place all the `MMRec/data` based on the github(Microlens data)
# - Add the `MMRec/src/inference.py` from github

# %% [markdown]
# # Note
# - Since the code has dependency/issue with the Config they use it is difficult to save the model, load the model and do inference.
#
# - The only easy solution I found was to train the model, and then **use the same config as training** and then do inference from the test_data batch(you can see what I did on the `quick_inference.py`)

# %%
# !pip install lmdb
# !pip install colorlog
# !pip install tensorboardX
# !pip install colorama
# !pip install torch
# !pip install -q torch-geometric
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 6.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 3.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.1/63.1 kB 2.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 23.1 MB/s eta 0:00:00

# %% [markdown]
# Following code will train for atleast 1(by default). And will conduct inference and give out the prediction

# %%
# !CUDA_LAUNCH_BLOCKING=1 python /content/MMRec/src/inference.py --model GRCN --dataset /content/MMRec/src/configs/dataset/microlens
# Out:
# Loading configuration files: ['/content/MMRec/src/configs/overall.yaml', '/content/MMRec/src/configs/dataset/microlens.yaml', '/content/MMRec/src/configs/model/GRCN.yaml']
# ...
